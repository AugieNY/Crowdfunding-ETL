# %%
# Import the Pandas dependency.
import pandas as pd
import regex as re


# Read the contacts string data into a Pandas DataFrame
contacts_string_df = pd.read_csv("./contacts_string_data.csv")
contacts_string_df.head()
# Out:
#                                         contact_info
# 0  contact_id 4661 name Cecilia Velasco email cec...
# 1  contact_id 3765 name Mariana Ellis email maria...
# 2  contact_id 4187 name Sofie Woods email sofie.w...
# 3  contact_id 4941 name Jeanette Iannotti email j...
# 4  contact_id 2199 name Samuel Sorgatz email samu...

# %%
# Extract the four-digit contact ID number.
contacts_string_df['contact_id'] = contacts_string_df['contact_info'].str.extract(r'(\d{4})')
contacts_string_df.head()
# Out:
#                                         contact_info contact_id
# 0  contact_id 4661 name Cecilia Velasco email cec...       4661
# 1  contact_id 3765 name Mariana Ellis email maria...       3765
# 2  contact_id 4187 name Sofie Woods email sofie.w...       4187
# 3  contact_id 4941 name Jeanette Iannotti email j...       4941
# 4  contact_id 2199 name Samuel Sorgatz email samu...       2199

# %%
# Extract the first and last name after the word "name". 
contacts_string_df['name'] = contacts_string_df['contact_info'].str.extract(r'([^name\s+][A-Za-z]+\s+[A-Za-z]+)')
contacts_string_df.head()
# Out:
#                                         contact_info contact_id  \
# 0  contact_id 4661 name Cecilia Velasco email cec...       4661
# 1  contact_id 3765 name Mariana Ellis email maria...       3765
# 2  contact_id 4187 name Sofie Woods email sofie.w...       4187
# 3  contact_id 4941 name Jeanette Iannotti email j...       4941
# 4  contact_id 2199 name Samuel Sorgatz email samu...       2199
#
#                 name
# 0    Cecilia Velasco
# 1      Mariana Ellis
# 2        Sofie Woods
# 3  Jeanette Iannotti
# 4     Samuel Sorgatz

# %%
contacts_string_df['email'] = contacts_string_df['contact_info'].str.extract(r'(\S+@\S+)')
contacts_string_df.head()
# Out:
#                                         contact_info contact_id  \
# 0  contact_id 4661 name Cecilia Velasco email cec...       4661
# 1  contact_id 3765 name Mariana Ellis email maria...       3765
# 2  contact_id 4187 name Sofie Woods email sofie.w...       4187
# 3  contact_id 4941 name Jeanette Iannotti email j...       4941
# 4  contact_id 2199 name Samuel Sorgatz email samu...       2199
#
#                 name                         email
# 0    Cecilia Velasco  cecilia.velasco@rodrigues.fr
# 1      Mariana Ellis       mariana.ellis@rossi.org
# 2        Sofie Woods       sofie.woods@riviere.com
# 3  Jeanette Iannotti   jeanette.iannotti@yahoo.com
# 4     Samuel Sorgatz      samuel.sorgatz@gmail.com

# %%
category_df=pd.read_csv("./category.csv")
category_df.head(10)
# Out:
#   category_id      category
# 0       cat01          food
# 1       cat02         music
# 2       cat03    technology
# 3       cat04       theater
# 4       cat05  film & video
# 5       cat06    publishing
# 6       cat07         games
# 7       cat08   photography
# 8       cat09    journalism

# %%
subcategory_df=pd.read_csv("./subcategory.csv")
subcategory_df.head(10)
# Out:
#   subcategory_id     subcategory
# 0         scat01     food trucks
# 1         scat02            rock
# 2         scat03             web
# 3         scat04           plays
# 4         scat05     documentary
# 5         scat06  electric music
# 6         scat07           drama
# 7         scat08      indie rock
# 8         scat09       wearables
# 9        scat010      nonfiction

# %%
campaign_df=pd.read_csv("./campaign.csv")
campaign_df.head(2)
# Out:
#    cf_id                company_name                           description  \
# 0    147  Baldwin, Riley and Jackson  Pre-emptive tertiary standardization
# 1   1621                    Odom Inc      Managed bottom-line architecture
#
#      goal  pledged     outcome  backers_count country currency launched_date  \
# 0   100.0      0.0      failed              0      CA      CAD    2020-02-13
# 1  1400.0  14560.0  successful            158      US      USD    2021-01-25
#
#      end_date sub-category category_id subcategory_id  contact_id
# 0  2021-03-01  food trucks       cat01         scat01        4661
# 1  2021-05-25         rock       cat02         scat02        3765

# %%
contacts_df=pd.read_csv("./contacts.csv")
contacts_df.head(2)
# Out:
#    contact_id first_name last_name                         email
# 0        4661    Cecilia   Velasco  cecilia.velasco@rodrigues.fr
# 1        3765    Mariana     Ellis       mariana.ellis@rossi.org
